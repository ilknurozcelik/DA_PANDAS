# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\user\\PANDAS'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F683-A709
#
#  Directory of C:\Users\user\PANDAS
#
# 27.04.2022  10:18    <DIR>          .
# 27.04.2022  10:18    <DIR>          ..
# 27.04.2022  10:09    <DIR>          .ipynb_checkpoints
# 20.04.2022  15:30           565.402 00-Series.ipynb
# 23.04.2022  21:34           208.969 01-DataFrames.ipynb
# 25.04.2022  00:26           194.603 02-Conditional-Filtering.ipynb
# 26.04.2022  17:56           196.397 03-Useful-Methods.ipynb
# 26.04.2022  18:43            64.239 04-Missing-Data.ipynb
# 20.04.2022  15:14           219.627 05-Groupby-Operations-and-MultiIndex.ipynb
# 20.04.2022  15:14            62.966 06-Combining-DataFrames.ipynb
# 20.04.2022  15:14            32.972 07-Text-Methods.ipynb
# 20.04.2022  15:14            93.392 08-Time-Methods.ipynb
# 20.04.2022  15:14            65.234 09-Inputs-and-Outputs.ipynb
# 20.04.2022  15:14           101.081 10-Pivot-Tables.ipynb
# ...

# %%
df2 = pd.read_csv("C:\\Users\\user\\PANDAS\\tips.csv")

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[df["price_per_person"].notna()].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["age"].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
df[df["age"].notna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# loc/iloc

# %%
df.iloc[10:25]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
# ...

# %%
df.iloc[10:25, 3:8]
# Out:
#      age  sibsp  parch     fare embarked
# 10   4.0      1      1  16.7000        S
# 11  58.0      0      0  26.5500        S
# 12  20.0      0      0   8.0500        S
# 13  39.0      1      5  31.2750        S
# 14  14.0      0      0   7.8542        S
# 15  55.0      0      0  16.0000        S
# 16   2.0      4      1  29.1250        Q
# 17   NaN      0      0  13.0000        S
# 18  31.0      1      0  18.0000        S
# 19   NaN      0      0   7.2250        C
# 20  35.0      0      0  26.0000        S
# 21  34.0      0      0  13.0000        S
# 22  15.0      0      0   8.0292        Q
# 23  28.0      0      0  35.5000        S
# 24   8.0      3      1  21.0750        S

# %%
df.iloc[:, 3:5].head()
# Out:
#     age  sibsp
# 0  22.0      1
# 1  38.0      1
# 2  26.0      0
# 3  35.0      1
# 4  35.0      0

# %%
df.iloc[[3, 5, 8], 2:8]
# Out:
#       sex   age  sibsp  parch     fare embarked
# 3  female  35.0      1      0  53.1000        S
# 5    male   NaN      0      0   8.4583        Q
# 8  female  27.0      0      2  11.1333        S

# %%
df.iloc[2:10, [1,5,9]]
# Out:
#    pclass  parch    who
# 2       3      0  woman
# 3       1      0  woman
# 4       3      0    man
# 5       3      0    man
# 6       1      0    man
# 7       3      1  child
# 8       3      2  woman
# 9       2      0  child

# %%
df.iloc[2:10]["who"]
# Out:
# 2    woman
# 3    woman
# 4      man
# 5      man
# 6      man
# 7    child
# 8    woman
# 9    child
# Name: who, dtype: object

# %%
type(df.iloc[2:10]["who"])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[df["survived"] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[:, ["age", "fare", "who"]]
# Out:
#       age     fare    who
# 0    22.0   7.2500    man
# 1    38.0  71.2833  woman
# 2    26.0   7.9250  woman
# 3    35.0  53.1000  woman
# 4    35.0   8.0500    man
# ..    ...      ...    ...
# 886  27.0  13.0000    man
# 887  19.0  30.0000  woman
# 888   NaN  23.4500  woman
# 889  26.0  30.0000    man
# 890  32.0   7.7500    man
#
# [891 rows x 3 columns]

# %%
df[["who", "age", "fare"]]
# Out:
#        who   age     fare
# 0      man  22.0   7.2500
# 1    woman  38.0  71.2833
# 2    woman  26.0   7.9250
# 3    woman  35.0  53.1000
# 4      man  35.0   8.0500
# ..     ...   ...      ...
# 886    man  27.0  13.0000
# 887  woman  19.0  30.0000
# 888  woman   NaN  23.4500
# 889    man  26.0  30.0000
# 890    man  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df3 = df2.set_index("Payment ID")

# %%
df3.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df3.loc["Sun2959"]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df3.loc[["Sun2959", "Sun5260"]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df3.reset_index().head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
np.empty((5,5), int)  # incelenecek!!
# Out:
# array([[-818349624,        642,         64,          0,          0],
#        [         0,          0,          0,          0,  825242417],
#        [ 825845297,  942879033,  959984486, 1714644275,  912669030],
#        [ 909258802, 1664627257, 1714447205, 1647392311,  946156343],
#        [ 825307705,  895627314,  859071843,  942694969,  808674872]])

# %%
df4 = df.iloc[:10]

# %%
df4
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df5 = df2.iloc[:10]

# %%
df5
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df5.set_index("Payment ID", inplace=True)

# %%
df5
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# Sun5985           8.77  2.00    Male     No  Sun  Dinner     2
# Sun8157          26.88  3.12    Male     No  Sun  Dinner     4
# Sun6820          15.04  1.96    Male     No  Sun  Dinner     2
# Sun3775          14.78  3.23    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# ...

# %%
df4.reindex_like(df5)
# Out:
#             total_bill  tip  sex  smoker  day  time  size  price_per_person  \
# Payment ID
# Sun2959            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun4608            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun4458            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun5260            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun2251            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun9679            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun5985            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun8157            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun6820            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
# Sun3775            NaN  NaN  NaN     NaN  NaN   NaN   NaN               NaN
#
#             Payer Name  CC Number
# Payment ID
# Sun2959            NaN        NaN
# Sun4608            NaN        NaN
# ...

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df2["tip_percentage"] = 100* df2["tip"] /df2["total_bill"]

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
type(df2["tip_percentage"])
# Out:
# pandas.core.series.Series

# %%
df2["yeni kolon"] = 5

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  yeni kolon
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673           5
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159           5
# 2      Travis Walters  6011812112971322    Sun4458       16.658734           5
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041           5
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765           5

# %%
df2["tip_percentage"] = np.round(df2["tip_percentage"], 2)

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  yeni kolon
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94           5
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05           5
# 2      Travis Walters  6011812112971322    Sun4458           16.66           5
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98           5
# 4        Tonya Carter  4832732618637221    Sun2251           14.68           5

# %%
df2 = df2.drop("tip_percentage", axis=1)

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  yeni kolon
# 0  Christy Cunningham  3560325168603410    Sun2959           5
# 1      Douglas Tucker  4478071379779230    Sun4608           5
# 2      Travis Walters  6011812112971322    Sun4458           5
# 3    Nathaniel Harris  4676137647685994    Sun5260           5
# 4        Tonya Carter  4832732618637221    Sun2251           5

# %%
df2.drop(columns = ["tip", "time"]).head()
# Out:
#    total_bill     sex smoker  day  size  price_per_person          Payer Name  \
# 0       16.99  Female     No  Sun     2              8.49  Christy Cunningham
# 1       10.34    Male     No  Sun     3              3.45      Douglas Tucker
# 2       21.01    Male     No  Sun     3              7.00      Travis Walters
# 3       23.68    Male     No  Sun     2             11.84    Nathaniel Harris
# 4       24.59  Female     No  Sun     4              6.15        Tonya Carter
#
#           CC Number Payment ID  yeni kolon
# 0  3560325168603410    Sun2959           5
# 1  4478071379779230    Sun4608           5
# 2  6011812112971322    Sun4458           5
# 3  4676137647685994    Sun5260           5
# 4  4832732618637221    Sun2251           5

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  yeni kolon
# 0  Christy Cunningham  3560325168603410    Sun2959           5
# 1      Douglas Tucker  4478071379779230    Sun4608           5
# 2      Travis Walters  6011812112971322    Sun4458           5
# 3    Nathaniel Harris  4676137647685994    Sun5260           5
# 4        Tonya Carter  4832732618637221    Sun2251           5

# %%
df2.drop([2,5])
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  yeni kolon
# ...

# %%
df2.drop(index=[3, 8], columns=["tip"]).head(10)
# Out:
#     total_bill     sex smoker  day    time  size  price_per_person  \
# 0        16.99  Female     No  Sun  Dinner     2              8.49
# 1        10.34    Male     No  Sun  Dinner     3              3.45
# 2        21.01    Male     No  Sun  Dinner     3              7.00
# 4        24.59  Female     No  Sun  Dinner     4              6.15
# 5        25.29    Male     No  Sun  Dinner     4              6.32
# 6         8.77    Male     No  Sun  Dinner     2              4.38
# 7        26.88    Male     No  Sun  Dinner     4              6.72
# 9        14.78    Male     No  Sun  Dinner     2              7.39
# 10       10.27    Male     No  Sun  Dinner     2              5.14
# 11       35.26  Female     No  Sun  Dinner     4              8.82
#
#             Payer Name         CC Number Payment ID  yeni kolon
# 0   Christy Cunningham  3560325168603410    Sun2959           5
# 1       Douglas Tucker  4478071379779230    Sun4608           5
# ...

# %%
df2.drop(index=np.arange(3,8), columns=["tip"]).head(10)
# Out:
#     total_bill     sex smoker  day    time  size  price_per_person  \
# 0        16.99  Female     No  Sun  Dinner     2              8.49
# 1        10.34    Male     No  Sun  Dinner     3              3.45
# 2        21.01    Male     No  Sun  Dinner     3              7.00
# 8        15.04    Male     No  Sun  Dinner     2              7.52
# 9        14.78    Male     No  Sun  Dinner     2              7.39
# 10       10.27    Male     No  Sun  Dinner     2              5.14
# 11       35.26  Female     No  Sun  Dinner     4              8.82
# 12       15.42    Male     No  Sun  Dinner     2              7.71
# 13       18.43    Male     No  Sun  Dinner     4              4.61
# 14       14.83  Female     No  Sun  Dinner     2              7.42
#
#             Payer Name         CC Number Payment ID  yeni kolon
# 0   Christy Cunningham  3560325168603410    Sun2959           5
# 1       Douglas Tucker  4478071379779230    Sun4608           5
# ...

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  yeni kolon
# 0  Christy Cunningham  3560325168603410    Sun2959           5
# 1      Douglas Tucker  4478071379779230    Sun4608           5
# 2      Travis Walters  6011812112971322    Sun4458           5
# 3    Nathaniel Harris  4676137647685994    Sun5260           5
# 4        Tonya Carter  4832732618637221    Sun2251           5

# %%
df2.shape
# Out:
# (244, 12)

# %%
df2.ndim
# Out:
# 2

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  yeni kolon
# 0  Christy Cunningham  3560325168603410    Sun2959           5
# 1      Douglas Tucker  4478071379779230    Sun4608           5
# 2      Travis Walters  6011812112971322    Sun4458           5
# 3    Nathaniel Harris  4676137647685994    Sun5260           5
# 4        Tonya Carter  4832732618637221    Sun2251           5

# %%
one_row= df2.iloc[0]

# %%
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# yeni kolon                           5
# Name: 0, dtype: object

# %%
df2.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID  yeni kolon
# 239    Michael Avila  5296068606052842    Sat2657           5
# 240   Monica Sanders  3506806155565404    Sat1766           5
# 241       Keith Wong  6011891618747196    Sat3880           5
# 242     Dennis Dixon     4375220550950      Sat17           5
# 243  Michelle Hardin  3511451626698139    Thur672           5

# %%
df2.append(one_row).tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID  yeni kolon
# 240      Monica Sanders  3506806155565404    Sat1766           5
# 241          Keith Wong  6011891618747196    Sat3880           5
# 242        Dennis Dixon     4375220550950      Sat17           5
# 243     Michelle Hardin  3511451626698139    Thur672           5
# 0    Christy Cunningham  3560325168603410    Sun2959           5

# %%
df2.size
# Out:
# 2928

# %%
df2.drop(243).tail()
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#          Payer Name         CC Number Payment ID  yeni kolon
# 238  Kimberly Crane      676184013727    Sat9777           5
# 239   Michael Avila  5296068606052842    Sat2657           5
# 240  Monica Sanders  3506806155565404    Sat1766           5
# 241      Keith Wong  6011891618747196    Sat3880           5
# 242    Dennis Dixon     4375220550950      Sat17           5

# %%
df2[(df2["total_bill"] > 30) & ~(df2["day"] == "Sun")]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2             16.34
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# ...
